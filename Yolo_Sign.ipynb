# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/yolo_custom_model_Training
# Out:
# /content/drive/MyDrive/yolo_custom_model_Training

# %%
# !unzip custom_data.zip

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/darknet'
# Out:
# Cloning into '/content/darknet'...
# remote: Enumerating objects: 15502, done.
# remote: Total 15502 (delta 0), reused 0 (delta 0), pack-reused 15502
# Receiving objects: 100% (15502/15502), 14.17 MiB | 16.14 MiB/s, done.
# Resolving deltas: 100% (10403/10403), done.

# %%
# %cd '/content/darknet'
# Out:
# /content/darknet

# %%
# !ls
# Out:
# 3rdparty		darknet_video.py       net_cam_v4.sh
# build			data		       README.md
# build.ps1		image_yolov3.sh        results
# cfg			image_yolov4.sh        scripts
# cmake			include		       src
# CMakeLists.txt		json_mjpeg_streams.sh  vcpkg.json
# DarknetConfig.cmake.in	LICENSE		       video_yolov3.sh
# darknet_images.py	Makefile	       video_yolov4.sh
# darknet.py		net_cam_v3.sh

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !/content/darknet/darknet
# Out:
# usage: /content/darknet/darknet <function>

# %%
# %cd /content/drive/MyDrive/yolo_custom_model_Training
# Out:
# /content/drive/MyDrive/yolo_custom_model_Training

# %%
# !ls
# Out:
# backup	custom_data  custom_data.zip

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2023-02-17 19:40:13--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  16.9MB/s    in 10s
#
# 2023-02-17 19:40:24 (15.0 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !ls
# Out:
# backup	custom_data  custom_data.zip  darknet53.conv.74

# %%
# !/content/darknet/darknet detector train custom_data/labelled_data.data /content/darknet/cfg/yolov3_custom.cfg darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 11060 (11060), cuDNN: 8.4.0, GPU count: 1
#  OpenCV version: 4.2.0
# yolov3_custom
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 256, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
